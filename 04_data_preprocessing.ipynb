# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("BAF.csv")

# %%
def categorical_to_numerical(df):
    categorical_columns = df.select_dtypes(include = ['str']).columns.to_list()
    le = LabelEncoder()
    for i in categorical_columns:
        df[i] = le.fit_transform(df[i])
    return df

# %%
df = categorical_to_numerical(df)
df
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0                0     0.3               0.986506                         -1
# 1                0     0.8               0.617426                         -1
# 2                0     0.8               0.996707                          9
# 3                0     0.6               0.475100                         11
# 4                0     0.9               0.842307                         -1
# ...            ...     ...                    ...                        ...
# 999995           0     0.8               0.124690                         -1
# 999996           0     0.9               0.824544                         -1
# 999997           0     0.8               0.140891                         -1
# 999998           0     0.9               0.002480                         52
# 999999           0     0.6               0.993391                         -1
#
# ...

# %%
df.to_csv('C:/Users/wwwmy/Music/Bank Fraud Detection MLOps project/Data/preprocessed_data.csv', index=False)
